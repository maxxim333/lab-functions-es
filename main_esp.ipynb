# %% [markdown]
# # Functions

# %% [markdown]
# En este laboratorio pondremos en práctica algunos de los conceptos que hemos aprendido en los últimos días.
#
# `NOTA: En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando solo la sintaxis más básica de Python y sin funciones como len, count, sum, max, min, in, etc. Dale una oportunidad. 🧑🏻‍💻👩🏻‍💻`
#
# La celda después de cada ejercicio contiene algunas pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
def greater(a,b):
    greatest=max(a,b)
    return greatest

# %%
# Para testear tu función
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.050s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más

# %%
#tu codigo aquí

# %%
# Para testear tu función
test_greatest(greatest)

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
def sum_all(lst):
    suma = sum(lst)
    return suma

# %%
# Para testear tu función
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.044s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
def mult_all(lst):
#tu codigo aquí

# %%
# Para testear tu función
test_mult(mult_all)

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
def oper_all(arr, oper = "*"):
    if oper == "*":
        result = reduce(lambda x, y: x * y, arr)
    if oper == "+":
        result = reduce(lambda x, y: x + y, arr)
    return result

print(oper_all([1,2,3,4], "+"))
# Out:
# 10

# %%
# Para testear tu función
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.252s
#
# OK

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
def factorial(n):
#tu codigo aquí

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
# This will test your function 
test_factorial(factorial)

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
def unique(lst_un):
    unique_list = []
    for item in lst_un:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

print(unique([-2, 1, 2, 3, 1, 2, 1, 4, 2, 1]))
# Out:
# [-2, 1, 2, 3, 4]

# %%
# Para testear tu función 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.373s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
def mode_counter(arr):
#tu codigo aqu

# %%
# Para testear tu función 
test_mode(mode_counter)

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
def st_dev(list_sd):
    result = ((sum([abs(((i) + sum(list_sd)/len(list_sd))) for i in list_sd]))/len(list_sd))
    return result
    
print(st_dev(([-2, 1, 2, 3, 2])))
# Out:
# 2.72

# %%
# Para testear tu función
test_stdev(st_dev)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 642.9421487603305 != 649.013307049457 within 5 delta (6.071158289126515 difference) : Should be 649.013307049457
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 495.8044938016529 != 586.1646908518654 within 5 delta (90.36019705021255 difference) : Should be 586.1646908518654
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 558.2926530612244 != 606.8585451230128 within 5 delta (48.56589206178842 difference) : Should be 606.8585451230128
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 515.564542936288 != 592.0739215295933 within 5 delta (76.50937859330531 difference) : Should be 592.0739215295933
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 510.22707827494514 != 588.0379458501814 within 5 delta (77.81086757523622 difference) : Should be 588.0379458501814
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 527.4006337709372 != 587.4959263346083 within 5 delta (60.09529256367102 difference) : Should be 587.4959263346083
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 550.2211652794293 != 573.9130162718958 within 5 delta (23.69185099246647 difference) : Should be 573.9130162718958
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 495.59704056018006 != 535.9916473015335 within 5 delta (40.394606741353414 difference) : Should be 535.9916473015335
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 434.0330578512396 != 478.0538400912328 within 5 delta (44.020782239993196 difference) : Should be 478.0538400912328
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 537.5621301775147 != 595.4487318885584 within 5 delta (57.88660171104368 difference) : Should be 595.4487318885584
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 485.78044363965586 != 552.4113981261469 within 5 delta (66.63095448649102 difference) : Should be 552.4113981261469
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 521.07125 != 593.8083687909374 within 5 delta (72.73711879093742 difference) : Should be 593.8083687909374
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 489.2857142857143 != 572.2047393514525 within 5 delta (82.91902506573825 difference) : Should be 572.2047393514525
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 721.5748721694667 != 622.160108976139 within 5 delta (99.41476319332776 difference) : Should be 622.160108976139
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 448.59221278641235 != 539.4700276597998 within 5 delta (90.87781487338748 difference) : Should be 539.4700276597998
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 428.5859375 != 514.0528142451253 within 5 delta (85.46687674512532 difference) : Should be 514.0528142451253
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 498.0321107266437 != 567.4754077273747 within 5 delta (69.44329700073098 difference) : Should be 567.4754077273747
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 473.6 != 536.2738891746701 within 5 delta (62.67388917467008 difference) : Should be 536.2738891746701
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 523.7612456747404 != 578.0387918814671 within 5 delta (54.2775462067267 difference) : Should be 578.0387918814671
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError:
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 461.8114353179289 != 510.4814558970425 within 5 delta (48.67002057911361 difference) : Should be 510.4814558970425
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 535.9642857142857 != 614.8453521703525 within 5 delta (78.88106645606683 difference) : Should be 614.8453521703525
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 471.646201873049 != 549.8512213239122 within 5 delta (78.20501945086323 difference) : Should be 549.8512213239122
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 522.6887052341598 != 604.6228512120529 within 5 delta (81.93414597789308 difference) : Should be 604.6228512120529
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 631.5840000000001 != 619.2056739619451 within 5 delta (12.378326038054979 difference) : Should be 619.2056739619451
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 522.8544423440453 != 613.1570026358852 within 5 delta (90.30256029183988 difference) : Should be 613.1570026358852
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 507.38285714285706 != 568.6084562074224 within 5 delta (61.2255990645653 difference) : Should be 568.6084562074224
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 555.6562880886428 != 638.8846459396792 within 5 delta (83.22835785103644 difference) : Should be 638.8846459396792
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 519.4171428571426 != 579.0356588353593 within 5 delta (59.61851597821669 difference) : Should be 579.0356588353593
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 469.7868480725624 != 548.9071541519661 within 5 delta (79.12030607940369 difference) : Should be 548.9071541519661
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 521.5200214995971 != 544.9831922008427 within 5 delta (23.463170701245645 difference) : Should be 544.9831922008427
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 488.462652784065 != 554.4123339877152 within 5 delta (65.94968120365019 difference) : Should be 554.4123339877152
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 708.1851851851851 != 670.2209371357802 within 5 delta (37.96424804940489 difference) : Should be 670.2209371357802
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 537.7653061224488 != 624.0109374125742 within 5 delta (86.2456312901254 difference) : Should be 624.0109374125742
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 476.0310640150966 != 568.9198660511496 within 5 delta (92.888802036053 difference) : Should be 568.9198660511496
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 465.9349480968858 != 544.4778286416747 within 5 delta (78.54288054478889 difference) : Should be 544.4778286416747
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 470.8864265927978 != 534.2334126402865 within 5 delta (63.346986047488656 difference) : Should be 534.2334126402865
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 559.2897238569489 != 627.2717891841554 within 5 delta (67.98206532720656 difference) : Should be 627.2717891841554
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 481.0816326530612 != 560.3336182456517 within 5 delta (79.25198559259047 difference) : Should be 560.3336182456517
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 518.0204081632653 != 590.8071283487 within 5 delta (72.78672018543466 difference) : Should be 590.8071283487
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 344.90909090909093 != 426.2665832551269 within 5 delta (81.35749234603594 difference) : Should be 426.2665832551269
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 543.7755555555555 != 584.9585592945486 within 5 delta (41.18300373899319 difference) : Should be 584.9585592945486
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 463.42791234140725 != 542.1299627124368 within 5 delta (78.7020503710296 difference) : Should be 542.1299627124368
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.246s
#
# FAILED (failures=99)

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
def pangram(string):
#tu codigo aquí

# %%
# Para testear tu función
test_pangram(pangram)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
def sort_alpha(string):
    words = []
    word = ''
    for char in string:
        if char != ',':
            word += char
        else:
            words.append(word)
            word = ''
    words.append(word)  
    
    sorted_words = sorted(words)
    
    sorted_string = ''
    for i, word in enumerate(sorted_words):
        sorted_string += word
        if i < len(sorted_words) - 1:
            sorted_string += ','  # Add comma except for the last word
    
    return sorted_string

# %%
# Para testear tu función 
test_alpha(sort_alpha)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.244s
#
# OK

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es.

# %%
def check_pass(password):
#tu codigo aquí

# %%
# Para testear tu función
test_pass(check_pass)
