# %% [markdown]
# # Functions

# %% [markdown]
# En este laboratorio pondremos en práctica algunos de los conceptos que hemos aprendido en los últimos días.
#
# `NOTA: En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando solo la sintaxis más básica de Python y sin funciones como len, count, sum, max, min, in, etc. Dale una oportunidad. 🧑🏻‍💻👩🏻‍💻`
#
# La celda después de cada ejercicio contiene algunas pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest
import os
# !pip3 install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/biomedmax/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 22.5 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 20.4 MB/s eta 0:00:0000:0100:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 15.7 MB/s eta 0:00:00
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 tzdata-2024.1

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
def greater(a,b):
    return max(a,b)

# %%
# Para testear tu función
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.054s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más

# %%
"""def greatest(x):
    return max(x, key=lambda i: i)

"""
from functools import reduce

def greatest(x):
    result = max(map(lambda i: x[i], range(len(x))))
    return result


greatest([1,2,3])
# Out:
# 3

# %%
# Para testear tu función
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.060s
#
# OK

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
def sum_all(lst):
    #suma=sum(lst)
    suma=reduce(lambda x,y: x+y, lst)
    return(suma)

sum_all([1,2,3])
# Out:
# 6

# %%
# Para testear tu función
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.053s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
def mult_all(lst):
    """
    if not lst:
        return 1  #if the list is empty
    else:
        return lst[0] * mult_all(lst[1:])
        """

    multiplica = reduce(lambda x,y: x*y, lst)
    return multiplica

# %%
# Para testear tu función
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.062s
#
# OK

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
def oper_all(arr, oper = "*"):
    """
    if oper == "*":
        return (lst[0] * mult_all(lst[1:]))
    if oper == "+":
        suma=sum(lst)
        return(suma)
        """



    operation = reduce(lambda x,y: x*y, arr) if oper == "*" else reduce(lambda x,y: x+y, arr)
    return operation

oper_all([1,2,3])
# Out:
# 6

# %%
# Para testear tu función
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.051s
#
# OK

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
def factorial(n):
    """
    result1 = 1
    for i in range(1, n+1):
        result1 *= i
    return result1 if n > 0 else "Numero tiene que ser positivo"
    """

    result = reduce(lambda x,y: x*y, range(1, n+1))

print((factorial(3)))
# Out:
# None

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.046s
#
# OK

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
def unique(lst_un):
    unique_list = []
    for item in lst_un:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

# %%
# Para testear tu función 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.074s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
def mode_counter(arr):
    dict_count = {}
    if not arr:
        return None
    for i in arr:
        dict_count[i] = dict_count.get(i, 0) + 1
        #print(dict_count)
    counter = max(dict_count.values())
    for x,y in dict_count.items():  #iterar pair de (key,value) en diccionario
        if y == counter:
            return x
    print(dict_count.values(x))

# %%
# Para testear tu función 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.051s
#
# OK

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
def st_dev(list_sd):
#tu codigo aquí

# %%
# Para testear tu función
test_stdev(st_dev)

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
import string #import the module of string that contains letters
def pangram(string):
    list3 = set(string)
    list_alfabeto = set(string.ascii_letters)
    return list3.issubset(list_alfabeto)

# %%
# Para testear tu función
test_pangram(pangram)
# Out:
# EEEEEEEEEEEEEEEEEEEEEEEEEEEEEE
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ======================================================================
# ERROR: runTest (mod.testing.test_pangram.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 172, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
#   File "/tmp/ipykernel_15804/4106697047.py", line 4, in pangram
#     list_alfabeto = set(string.ascii_letters)
# AttributeError: 'str' object has no attribute 'ascii_letters'
#
# ----------------------------------------------------------------------
# Ran 30 tests in 0.037s
#
# FAILED (errors=30)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
def sort_alpha(string):
    words = []
    word = ''
    for char in string:
        if char != ',':
            word += char
        else:
            words.append(word)
            word = ''
    words.append(word)  # Append the last word
    
    sorted_words = sorted(words)
    
    sorted_string = ''
    for i, word in enumerate(sorted_words):
        sorted_string += word
        if i < len(sorted_words) - 1:
            sorted_string += ','  # Add comma except for the last word
    
    return sorted_string

# %%
# Para testear tu función 
test_alpha(sort_alpha)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.051s
#
# OK

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es.

# %%
def check_pass(password):
    list4 =[i for i in password]
    check_length = len(list4)
    check_mayuscula = any(item.isupper() for item in list4)
    check_minuscula = any(item.islower() for item in list4)
    check_numero = any(item.isdigit() for item in list4)
    check_caracter = any(not item.isalnum() for item in list4)
    return "Si es fuerte" if check_length > 8 and check_mayuscula and check_minuscula and check_numero and check_caracter else "No lo es"
password = "isjsncs2*aDh"
print(check_pass(password))
# Out:
# Si es fuerte

# %%
# Para testear tu función
test_pass(check_pass)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'Si es fuerte' != True : Should be True
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ======================================================================
# FAIL: runTest (mod.testing.test_pass.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/biomedmax/github/lab-functions-es/mod/testing.py", line 202, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: 'No lo es' != False : Should be False
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.050s
#
# FAILED (failures=100)
